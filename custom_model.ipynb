# %%
# curl \
#   -H "Content-Type: application/json" \
#   -d "{\"contents\":[{\"parts\":[{\"text\":\"Explain how AI works\"}]}]}" \
#   -X POST "https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateContent?key=AIzaSyBf8C6HfF-kDeSftJy997uyqExAyEoAWgU"

# %%
import os

def rename_files_in_folder(folder_path):
    # Get all files in the folder
    files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    
    # Sort files to maintain order
    files.sort()

    # Rename files sequentially
    for index, file_name in enumerate(files, start=1):
        # Get the file extension
        file_extension = os.path.splitext(file_name)[1]
        # Create the new file name
        new_name = f"{index}{file_extension}"
        # Rename the file
        os.rename(os.path.join(folder_path, file_name), os.path.join(folder_path, new_name))
        print(f"Renamed: {file_name} -> {new_name}")

# Provide the folder path
folder_path = input("Enter the folder path: ")
rename_files_in_folder(folder_path)
# Out:
# Renamed: alpha_101962.jpg -> 1.jpg
# Renamed: alpha_76733.jpg -> 2.jpg
# Renamed: alpha_76740.jpg -> 3.jpg
# Renamed: alpha_76746.jpg -> 4.jpg
# Renamed: alpha_76751.jpg -> 5.jpg
# Renamed: alpha_77004.jpg -> 6.jpg
# Renamed: alpha_77011.jpg -> 7.jpg
# Renamed: alpha_77017.jpg -> 8.jpg
# Renamed: alpha_77022.jpg -> 9.jpg
# Renamed: alpha_77095.jpg -> 10.jpg
# Renamed: alpha_77106.jpg -> 11.jpg
# Renamed: alpha_77275.jpg -> 12.jpg
# Renamed: alpha_77282.jpg -> 13.jpg
# Renamed: alpha_77288.jpg -> 14.jpg
# Renamed: alpha_77293.jpg -> 15.jpg
# Renamed: alpha_77366.jpg -> 16.jpg
# Renamed: alpha_77377.jpg -> 17.jpg
# Renamed: alpha_77546.jpg -> 18.jpg
# Renamed: alpha_77553.jpg -> 19.jpg
# Renamed: alpha_77559.jpg -> 20.jpg
# Renamed: alpha_77564.jpg -> 21.jpg
# Renamed: alpha_77637.jpg -> 22.jpg
# Renamed: alpha_77648.jpg -> 23.jpg
# Renamed: alpha_77817.jpg -> 24.jpg
# Renamed: alpha_77824.jpg -> 25.jpg
# Renamed: alpha_77830.jpg -> 26.jpg
# Renamed: alpha_77835.jpg -> 27.jpg
# Renamed: alpha_77908.jpg -> 28.jpg
# Renamed: alpha_78088.jpg -> 29.jpg
# Renamed: alpha_78095.jpg -> 30.jpg
# Renamed: alpha_78101.jpg -> 31.jpg
# Renamed: alpha_78106.jpg -> 32.jpg
# Renamed: alpha_78179.jpg -> 33.jpg
# Renamed: alpha_78190.jpg -> 34.jpg
# Renamed: alpha_78359.jpg -> 35.jpg
# Renamed: alpha_78366.jpg -> 36.jpg
# Renamed: alpha_78372.jpg -> 37.jpg
# Renamed: alpha_78377.jpg -> 38.jpg
# Renamed: alpha_78450.jpg -> 39.jpg
# Renamed: alpha_78461.jpg -> 40.jpg
# Renamed: alpha_78999.jpg -> 41.jpg
# Renamed: alpha_79063.jpg -> 42.jpg
# Renamed: alpha_79738.jpg -> 43.jpg
# Renamed: alpha_80064.jpg -> 44.jpg
# Renamed: alpha_80239.jpg -> 45.jpg
# Renamed: alpha_80308.jpg -> 46.jpg
# Renamed: alpha_80381.jpg -> 47.jpg
# Renamed: alpha_80512.jpg -> 48.jpg
# Renamed: alpha_80853.jpg -> 49.jpg
# Renamed: alpha_81210.jpg -> 50.jpg
# Renamed: alpha_81801.jpg -> 51.jpg
# Renamed: alpha_82029.jpg -> 52.jpg
# Renamed: alpha_82032.jpg -> 53.jpg
# Renamed: alpha_82188.jpg -> 54.jpg
# Renamed: alpha_82542.jpg -> 55.jpg
# Renamed: alpha_82782.jpg -> 56.jpg
# Renamed: alpha_82902.jpg -> 57.jpg
# Renamed: alpha_83002.jpg -> 58.jpg
# Renamed: alpha_83329.jpg -> 59.jpg
# Renamed: alpha_83464.jpg -> 60.jpg
# Renamed: alpha_83530.jpg -> 61.jpg
# Renamed: alpha_83625.jpg -> 62.jpg
# Renamed: alpha_83664.jpg -> 63.jpg
# Renamed: alpha_83945.jpg -> 64.jpg
# Renamed: alpha_84343.jpg -> 65.jpg
# Renamed: alpha_84466.jpg -> 66.jpg
# Renamed: alpha_84540.jpg -> 67.jpg
# Renamed: alpha_84592.jpg -> 68.jpg
# Renamed: alpha_84698.jpg -> 69.jpg
# Renamed: alpha_85105.jpg -> 70.jpg
# Renamed: alpha_85549.jpg -> 71.jpg
# Renamed: alpha_85967.jpg -> 72.jpg
# Renamed: alpha_86199.jpg -> 73.jpg
# Renamed: alpha_86419.jpg -> 74.jpg
# Renamed: alpha_86775.jpg -> 75.jpg
# Renamed: alpha_86994.jpg -> 76.jpg
# Renamed: alpha_87070.jpg -> 77.jpg
# Renamed: alpha_87218.jpg -> 78.jpg
# Renamed: alpha_87347.jpg -> 79.jpg
# Renamed: alpha_87584.jpg -> 80.jpg
# Renamed: alpha_88124.jpg -> 81.jpg
# Renamed: alpha_88391.jpg -> 82.jpg
# Renamed: alpha_88875.jpg -> 83.jpg
# Renamed: alpha_89147.jpg -> 84.jpg
# Renamed: alpha_89187.jpg -> 85.jpg
# Renamed: alpha_89614.jpg -> 86.jpg
# Renamed: alpha_89773.jpg -> 87.jpg
# Renamed: alpha_89809.jpg -> 88.jpg
# Renamed: alpha_90075.jpg -> 89.jpg
# Renamed: alpha_90096.jpg -> 90.jpg
# Renamed: alpha_90366.jpg -> 91.jpg
# Renamed: alpha_90640.jpg -> 92.jpg
# Renamed: alpha_90847.jpg -> 93.jpg
# Renamed: alpha_91213.jpg -> 94.jpg
# Renamed: alpha_91505.jpg -> 95.jpg
# Renamed: alpha_92306.jpg -> 96.jpg
# Renamed: alpha_92743.jpg -> 97.jpg
# Renamed: alpha_93073.jpg -> 98.jpg
# Renamed: alpha_93866.jpg -> 99.jpg
# Renamed: alpha_93869.jpg -> 100.jpg
# Renamed: alpha_93874.jpg -> 101.jpg
# Renamed: alpha_95696.jpg -> 102.jpg
# Renamed: alpha_95772.jpg -> 103.jpg
